# %%
import pandas as pd
import csv

df=pd.read_csv('TargetData/TimeProvince.csv')
f2 = open('TimeAge2.csv','w')
wdr = csv.writer(f2)

oldC = 0
oldR = 0
oldD = 0
new=[]
copy=[]


for line in df[df['province']=='Seoul'].values:
    new=[line[0],line[1],line[2],line[3]-oldC,line[4]-oldR, line[5]-oldD]
    oldC = line[3]
    oldR = line[4]
    oldD = line[5]
    copy.append(new)
print(copy)
for a in copyByAge:
    wdr.writerows(a)
f2.close()
# Out:
# [['2020-01-20', 16, 'Seoul', 0, 0, 0], ['2020-01-21', 16, 'Seoul', 0, 0, 0], ['2020-01-22', 16, 'Seoul', 0, 0, 0], ['2020-01-23', 16, 'Seoul', 0, 0, 0], ['2020-01-24', 16, 'Seoul', 0, 0, 0], ['2020-01-25', 16, 'Seoul', 0, 0, 0], ['2020-01-26', 16, 'Seoul', 0, 0, 0], ['2020-01-27', 16, 'Seoul', 1, 0, 0], ['2020-01-28', 16, 'Seoul', 0, 0, 0], ['2020-01-29', 16, 'Seoul', 0, 0, 0], ['2020-01-30', 16, 'Seoul', 2, 0, 0], ['2020-01-31', 16, 'Seoul', 1, 0, 0], ['2020-02-01', 16, 'Seoul', 0, 0, 0], ['2020-02-02', 16, 'Seoul', 1, 0, 0], ['2020-02-03', 16, 'Seoul', 0, 0, 0], ['2020-02-04', 16, 'Seoul', 0, 0, 0], ['2020-02-05', 16, 'Seoul', 0, 1, 0], ['2020-02-06', 16, 'Seoul', 5, 0, 0], ['2020-02-07', 16, 'Seoul', 1, 0, 0], ['2020-02-08', 16, 'Seoul', 0, 0, 0], ['2020-02-09', 16, 'Seoul', 3, 0, 0], ['2020-02-10', 16, 'Seoul', 0, 0, 0], ['2020-02-11', 16, 'Seoul', 0, 1, 0], ['2020-02-12', 16, 'Seoul', 0, 0, 0], ['2020-02-13', 16, 'Seoul', 0, 0, 0], ['2020-02-14', 16, 'Seoul', 0, 0, 0], ['2020-02
# ...
